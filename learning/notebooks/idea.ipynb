# %% [markdown]
# Sagodi 是通过微扰的方法, 从 classical continous attractor 导出 ghost attractor, 然后研究其 FP 的. 然而, 目前的 learning rule 不是通过微扰得到的, 而是学习之后的结果. 如果其能作为一个 ghost attractor 工作, 应该可以恢复得到一个 classical continuous attractor.
#
# Clark 通过 DMFT 可以得到 classical CA, 但是要求神经元数量非常多($>10^{4}$), 和目前的小模型和 Ramesan 的 3-GRU network 格格不入.
#
# 能够像 Clark 一样, 通过某种方式恢复 heterogeneous 网络的等效 Classic continuous attractor 吗?
